# %%
#Write a program to print the 4th element from first and 4th element from last in a tuple
numbers=(10,20,30,40,50,60,70,80,90)
print("Tuple:", numbers)
print("4th element from first:", numbers[3])
print("4th element from last:", numbers[-4])
# Out:
# Tuple: (10, 20, 30, 40, 50, 60, 70, 80, 90)
# 4th element from first: 40
# 4th element from last: 60

# %%
#Write a program to check whether an element exists in a tuple or not 
numbers=(10,20,30,40,50)
element= int(input("Enter element to search:"))
if element in numbers:
    print("Element exists in the Tuple")
else:
    print("Element does not exist in the Tuple")
# Out:
# Enter element to search: 45
# Element does not exist in the Tuple

# %%
#Write a program to convert a list into a tuple
numbers_list=[10,20,30,40,50]
numbers_tuple=tuple(numbers_list)
print("List:", numbers_list)
print("Tuple:", numbers_tuple)
# Out:
# List: [10, 20, 30, 40, 50]
# Tuple: (10, 20, 30, 40, 50)

# %%
#Write a program to find the index of an item in a tuple
numbers=(10,20,30,40,50)
element=int(input("Enter element:"))
if element in numbers:
    print("Index of element:", numbers.index(element))
else:
    print("Element not found")
# Out:
# Enter element: 20
# Index of element: 1

# %%
#Write a program to replace last values of tuples in a list to 100
numbers = [(10,20,40),(40,50,60),(70,80,90)]
new_list=[]
for tup in numbers:
    new_tup = tup[:-1] + (100,)
    new_list.append(new_tup)
print("Original List:", numbers)
print("Updated List:", new_list)
# Out:
# Original List: [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
# Updated List: [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
#Write a python program to find the maximum and minimum element in a tuple
numbers = (25, 1, 45, 5, 60, 30)
maximum = max(numbers)
minimum = min(numbers)
print("Tuple:", numbers)
print("Maximum element:", maximum)
print("Minimum element:", minimum)
# Out:
# Tuple: (25, 1, 45, 5, 60, 30)
# Maximum element: 60
# Minimum element: 1

# %%
#Write a python program to swap the first and the last element of a tuple
numbers = (10,20,30,40,50)
new_tuple = (numbers[-1],) + numbers[1:-1] + (numbers[0],)
print("Original Tuple:", numbers)
print("Tuple after swapping:", new_tuple)
# Out:
# Original Tuple: (10, 20, 30, 40, 50)
# Tuple after swapping: (50, 20, 30, 40, 10)
